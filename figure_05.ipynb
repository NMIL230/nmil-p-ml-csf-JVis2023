# %% [markdown]
# # Figure 5: Active sampling for canonical multiple sclerosis phenotype

# %% [markdown]
# ## Manuscript Information
#
# "Contrast Response Function Estimation with Nonparametric Bayesian Active Learning"
# _Journal of Vision_
# https://www.medrxiv.org/content/10.1101/2023.05.11.23289869v2
#
# ## Lab and Institution Information
#
# NeuroMedical Informatics Lab
# Washington University in St. Louis
#
# ## Figure Description
#
# Display canonical multiple sclerosis phenotype Contrast Sensitivity Function (CSF) curve used in Experiment 1. Train 100 iterations of Gaussian Process machine learning with active learning stimulus selection on simulated data to calculate a Contrast Response Function (CRF).
#
# ## References
#
# Kalloniatis, Michael, and Charles Luu. “Visual Acuity.” In _Webvision: The Organization of the Retina and Visual System_, edited by Helga Kolb, Eduardo Fernandez, and Ralph Nelson. Salt Lake City (UT): University of Utah Health Sciences Center, 1995. http://www.ncbi.nlm.nih.gov/books/NBK11509/.

# %%
# Import libraries

import sys
import torch as pt
import gpytorch as gp
from utility.utils import *

import math
import numpy as np

import json
import datetime

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.gridspec import GridSpec
import seaborn as sns

# %% [markdown]
# Check versions of python, Gpytorch, and Pytorch dependencies

# %%
print("python version -->>", sys.version)
print("gpytorch version -->>", gp.__version__)
print("pytorch version -->>", pt.__version__)
# Out:
# python version -->> 3.10.9 (main, Mar  8 2023, 04:44:36) [Clang 14.0.6 ]
# gpytorch version -->> 1.8.1
# pytorch version -->> 1.13.1

# %% [markdown]
# This code was written for
#
# - python version 3.10.9
# - pytorch version 1.13.1
# - gpytorch version 1.8.1

# %%
# Run-time flags

verb_mode = True           # print verbose analyses?
scrn_mode = True           # plot on screen?
save_mode = True           # save plots in indicated directory?

# Fig A
plot_a_canon = True          # plot canonical CSF spline-interpolated curves?
plot_a_prior  = True         # plot GP posterior mean?
plot_a_thresh  = True        # plot 50% threshold curve of GP posterior mean?
plot_a_data = True           # plot actively learned data?

# Fig B
plot_b_rmse = True           # plot Root Mean Square Error of GP CSF estimation?
plot_b_canon = True          # plot canonical CSF spline-interpolated curves?
plot_b_thresh = True         # plot 50% threshold curve of prior?

# Fig C
plot_c_cdf = True            # plot the Cumulative Density Function 
plot_c_canonical = True

# Choose the raw frequency for Figure C
raw_freq_to_slice_at = 4     # cycles per degree
freq_to_slice_at = logFreq().forward(raw_freq_to_slice_at)

# dir to save to
save_dir = 'analysis/figure_05/'

# Save RMSE to text file
save_rmse = True
rmse_txt_path = f'{save_dir}rmses.txt'

# Individual print flags 
print_training_hyperparameters = False 
print_training_iters = False
print_progress_bar = False

# Set all to true if verb_mode
if verb_mode:
    print_training_hyperparameters = True
    print_training_iters = True
    print_progress_bar = False

# %%
# Constant Declarations

# Fix random seed
generative_random_seed = 1

# Which phenotypes are you considering?
# Store list of all Current phenos

data_dir = 'data/raw_data/'
data_file_name = 'csf_curves_exp1.json'
data_file_path = f'{data_dir}{data_file_name}'

csf_curves_exp1 = load_json_from_file(data_file_path)

all_phenos= {'MS'   : ('Multiple Sclerosis', csf_curves_exp1['multiple_sclerosis']),
             'Cat'  : ('Cataracts', csf_curves_exp1['cataracts']),
             'Norm' : ('Normal', csf_curves_exp1['normal']),
             'MA'   : ('Mild Amblyopia', csf_curves_exp1['mild_amblyopia'])}

# Which phenotypes are you considering among 'MS', 'Cat', 'Norm' and 'MA'?
calc_phenos = ['MS'] # should be same as filename
phenos = [all_phenos[pheno] for pheno in calc_phenos]

# Prior raw bounds
prior_raw_freq_min = 0.5
prior_raw_freq_max = 64
prior_raw_contrast_min = 1e-3
prior_raw_contrast_max = 1

# Prior bounds
prior_freq_min = logFreq().forward(prior_raw_freq_min)
prior_freq_max = logFreq().forward(prior_raw_freq_max)
prior_contrast_sensitivity_min = logContrast().forward(prior_raw_contrast_max)  # inverting-->max&min flipped 
prior_contrast_sensitivity_max = logContrast().forward(prior_raw_contrast_min)

# Create the bounds for the data
raw_freq_min = 1
raw_freq_max = 64
raw_contrast_min = 1e-3
raw_contrast_max = 1

# Define how to transform the data
x_min = logFreq().forward(raw_freq_min)
x_max = logFreq().forward(raw_freq_max)
y_min = logContrast().forward(raw_contrast_max)  # max and min get flipped when inverting
y_max = logContrast().forward(raw_contrast_min)

# transform the data
def normalize_to_unit_range(d):
    return scale_data_within_range(d, (0, 1), prior_freq_min, prior_freq_max, \
                                   prior_contrast_sensitivity_min, prior_contrast_sensitivity_max)

# marginal log resolutions of evaulation grid
x_resolution = 15  # 15 spatial frequencies per octave
y_resolution = 30  # 30 contrast units per decade

# for computing the proper prior threshold curve
psi_gamma  = 0.04  # guess rate is 4%
psi_lambda = 0.04  # lapse rate is 4%
psi_sigma = .08
sigmoid_type = 'logistic'

# training parameters?
num_halton_samples = 8
num_initial_points_training_iters = 500
num_new_points = 92
num_new_points_training_iters = 150
train_on_all_points_iters = 1500
sampling_strategy = 'active'
mean_module = 'constant_mean'
train_on_all_points_after_sampling = False
calculate_posterior = True
calculate_entropy = True

# Set raw ghost points 
raw_ghost_frequency = np.array([1, 2, 4, 8, 16, 32, 64, 128])
raw_ghost_contrast = np.array([5e-4, 5e-4, 5e-4, 5e-4, 5e-4, 5e-4, 5e-4, 1])

# GP hyperparameters?
learning_rate = .125
beta_for_regularization = .25
min_lengthscale = .15 # Note this changed from .2

# %%
# Standard plotting Parameters

###########
# GENERAL #
###########

fig_width = 6     # inches
fig_height = 4.5  # inches

dpi_val = 600              # graphics resolution
plt.rcParams['font.family'] = 'Arial'

# Figure A size is 9 by 7 inches, Figure B and Figure C are 3 by 3 inches.
fig_a_size = (9, 7)
fig_b_size = (3,3)
fig_c_size = (3,3)

# Composite figure size and configuration
figure_width = 13
figure_height = 6
num_plot_rows = 5
num_plot_columns = 2

# tick settings
axis_tick_params = {
    'axis':'both', 
    'which':'major', 
    'direction':'out'
}

# for "A", "B", "C" labels
subplot_label_font_size = 16
a_subplot_coords = (0.07, 0.89)
b_subplot_coords = (0.56, 0.89)
c_subplot_coords = (0.56, 0.45)


# Colorblind friendly palette	
colors = sns.color_palette('colorblind', n_colors=12)  # colorblind friendly palette
col1=0; col2=1; col3=2; col4=4

legend_font_size = 8
legend_font_weight = 'roman'
tick_font_size = 10
tick_font_weight = 'roman'
label_font_size = 12
label_font_weight = 'roman'
title_font_size = 14
title_font_weight = 'roman'
suptitle_font_size = 16
suptitle_font_weight = 'roman'


##########
# PLOT A #
##########

# plotting order -- higher on top
success_zorder = 5
fail_zorder = 4
thresh_zorder = 3
canon_zorder = 2
posterior_zorder = 1

# colors
a_latent_color = '#cf30cf'
a_mean_color = '#40E1D0'
success_color = 'blue'
failure_color = 'red'

# posterior
fig_a_cb_ticks = [0, .25, .5, .75, 1]
fig_a_cb_labs = [str(tick) for tick in fig_a_cb_ticks]
fig_a_cb_pad = .06
fig_a_cb_label_pad = -55
fig_a_cb_label = 'Detection Probability'
a_prior_color_gradient = 'gist_gray'
a_prior_grad_min = 0
a_prior_grad_max = 1

# marker dimensions
marker_size= 60            # marker size specified in pts
diamond_line_width = .8        # line width specified in pts
plus_line_width= .8
success_marker = '+'            
diamond_size = .4               # scaling constant
diamond_width = .152            # specified in cycles per degree
diamond_height = .10            # specified in log10(contrast)
diamond_fill_color = 'none'     # specify 'none' for transparent
success_label = 'success'       
failure_label = 'failure'

# threshold
a_linestyle= 'dashed'
a_dash_list = [(0, (10.0, 3.0))]
a_thresh_width = 2
num_curve_points = 1000         # large number of points to create curve  

# Figure A and B xticks and yticks
xticks_labels = np.array([1, 4, 16, 64])
yticks_labels = np.array([1, 0.1, 0.01, 0.001])
xticks_values = logFreq().forward(xticks_labels)
yticks_values = logContrast().forward(yticks_labels)

# save values
a_title  = 'Multiple_Sclerosis'
a_xlab = 'Spatial Frequency (cyc/deg)'
a_ylab = 'Contrast'
a_png_path = f"{save_dir}Figure05_{a_title.replace(' ', '_')}.png"
a_pdf_path = f"{save_dir}Figure05_{a_title.replace(' ', '_')}.pdf"

##########
# PLOT B #
##########

# colors
b_latent_color = 'dimgrey'
b_mean_color = '#40E1D0'

# labels
latent_label = 'ground truth'
mean_label = 'predicted'

# dash and legend
b_dash_tuple = (5.5, 3)
b_legend_location = 'lower left'
b_dash_list = a_dash_list

# rmse 
b_rmse_x_coord = 3.1
b_rmse_y_coord = 2.8

# save values
b_title = 'Threshold'
b_xlab = 'Spatial Frequency (cyc/deg)'
b_ylab = 'Contrast'
b_png_path = f"{save_dir}Figure05_B_{b_title.replace(' ', '_')}.png"
b_pdf_path = f"{save_dir}Figure05_B_{b_title.replace(' ', '_')}.pdf"
b_fig_pad = 0.2
b_bbox_mode = 'tight'

##########
# PLOT C #
##########

# colors
c_latent_color = 'dimgrey'
c_mean_color = '#40E1D0'

# dash and legend
c_dash = 10, 3
c_dash_symbol = '--'

# labels
c_xticks_labels = np.array([1, 0.1, 0.01, 0.001])
c_xticks_values = logContrast().forward(c_xticks_labels)
c_yticks_labels = ['0', '0.25', '0.5', '0.75', '1']
c_yticks_values = np.array([0, .25, .5, .75, 1])

# save values 
c_title = f'Probability at {raw_freq_to_slice_at} cyc/deg'
c_xlab = 'Contrast'
c_ylab = 'Detection Probability'
c_legend_location = 'lower left'
c_png_path = f"{save_dir}Figure05_C_{c_title.replace(' ', '_')}.png"
c_pdf_path = f"{save_dir}Figure05_C_{c_title.replace(' ', '_')}.pdf"

# %% [markdown]
# ## Perform analysis

# %%
# Initial Code executions

results = dict()
for i in range(len(phenos)):
    title, curve = phenos[i]

    ###################
    # CONSTRUCT CURVE #
    ###################
    set_random_seed(generative_random_seed)

    curve = np.array(curve)
    # prepare freqs - turn log10 to log2, and start from 0
    curve[:, 0] = (np.log2(10) * curve[:, 0]) - np.log2(.125)
    left, right, bottom, top = get_data_bounds(curve)
    cs = create_cubic_spline(curve)

    ###############
    # CREATE GRID #
    ###############

    # Make grid
    grid, xx, yy, xs, ys = create_evaluation_grid_resolution(x_min, x_max, y_min, y_max, \
                                                             x_resolution, y_resolution)

    ###################
    # ACTIVE LEARNING #
    ###################

    # we want the grid as a tensor to pass to get_best_entropy

    # create ghost points
    ghost_x1 = logFreq().forward(raw_ghost_frequency)
    ghost_x2 = logContrast().forward(raw_ghost_contrast)
    assert len(ghost_x1) == len(ghost_x2), "x1 and x2 have diff lengths"

    ghost_X = np.vstack((ghost_x1, ghost_x2)).T
    ghost_y = np.array([0]*len(ghost_x2))

    # create initial data points
    halton_X, halton_y = halton_samples_from_data(xx, yy, cs, psi_gamma, psi_lambda, num_halton_samples, \
                                                  sigmoid_type = sigmoid_type, psi_sigma = psi_sigma)

    # combine ghost and halton sampled points
    initial_Xs = np.vstack((ghost_X, halton_X))
    initial_ys = np.hstack((ghost_y, halton_y))

    # count number of ghost points and initial points
    num_initial_points = len(initial_ys)
    num_ghost_points = len(ghost_y)

    model, likelihood, X, y, rmse_list, entropy_list, posterior_list, _ = sample_and_train_gp(
        cs,
        grid,
        xx,
        yy,
        sampling_strategy= sampling_strategy,
        mean_module_name=mean_module,
        psi_sigma=psi_sigma,
        sigmoid_type=sigmoid_type,
        psi_gamma=psi_gamma,
        psi_lambda=psi_lambda,
        lr=learning_rate,
        num_initial_training_iters=num_initial_points_training_iters,
        num_new_points_training_iters=num_new_points_training_iters,
        num_new_points=num_new_points,
        beta_for_regularization=beta_for_regularization,
        train_on_all_points_after_sampling=train_on_all_points_after_sampling,
        train_on_all_points_iters= train_on_all_points_iters,
        phi=normalize_to_unit_range,
        print_training_hyperparameters=print_training_hyperparameters,
        print_training_iters=print_training_iters,
        progress_bar=print_progress_bar,
        min_lengthscale=min_lengthscale,
        calculate_rmse=(save_rmse or plot_b_rmse),
        calculate_entropy=calculate_entropy,
        calculate_posterior=calculate_posterior,
        initial_Xs=initial_Xs,
        initial_ys=initial_ys,
        num_ghost_points=num_ghost_points,
    )

    #################
    # EVALUATE GRID #
    #################

    # transform evaluation grid so it can be used by GP
    grid_transformed = transform_dataset(grid, phi=normalize_to_unit_range)

    # get the predictions on the eval grid
    zz = evaluate_posterior_mean(model, likelihood, grid_transformed).reshape(xx.shape)

    results[i] = {
        'xx': xx,
        'yy': yy,
        'zz': zz,
        'X': X,
        'y': y,
        'left': left,
        'right': right,
        'top': top,
        'bottom': bottom,
        'cs': cs,
        'psi_sigma': psi_sigma,
        'psi_gamma': psi_gamma,
        'psi_lambda': psi_lambda,
        'x_min': x_min,
        'x_max': x_max,
        'y_min': y_min,
        'y_max': y_max,
        'xs': xs,
        'ys': ys,
        'entropy_list': entropy_list,
        'initial_points': num_initial_points,
        'grid': grid,
        'model': model,
        'likelihood': likelihood,
        'f': normalize_to_unit_range,
        'rmse': rmse_list,
        'posterior_list': posterior_list,
    }
# Out:
# 1
# kernel 0 variance: tensor([[14.9397]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(4.9686, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2151]], grad_fn=<AddBackward0>)
# 2
# kernel 0 variance: tensor([[17.4711]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(7.0245, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 3
# kernel 0 variance: tensor([[18.7011]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(11.4211, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3094]], grad_fn=<AddBackward0>)
# 4
# kernel 0 variance: tensor([[18.3451]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(9.5807, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2153]], grad_fn=<AddBackward0>)
# 5
# kernel 0 variance: tensor([[18.0788]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.9619, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3124]], grad_fn=<AddBackward0>)
# 6
# kernel 0 variance: tensor([[18.5256]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.8503, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3152]], grad_fn=<AddBackward0>)
# 7
# kernel 0 variance: tensor([[17.8573]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.6410, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3153]], grad_fn=<AddBackward0>)
# 8
# kernel 0 variance: tensor([[17.9048]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.4878, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3175]], grad_fn=<AddBackward0>)
# kernel 0 variance: tensor([[17.9075]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.4910, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3176]], grad_fn=<AddBackward0>)
# 9
# kernel 0 variance: tensor([[30.6659]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(14.4340, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3145]], grad_fn=<AddBackward0>)
# 10
# kernel 0 variance: tensor([[41.1349]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(18.4241, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.3074]], grad_fn=<AddBackward0>)
# 11
# kernel 0 variance: tensor([[47.8774]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(20.4759, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2154]], grad_fn=<AddBackward0>)
# 12
# kernel 0 variance: tensor([[53.1571]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(24.2436, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2155]], grad_fn=<AddBackward0>)
# 13
# kernel 0 variance: tensor([[58.3113]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(28.3471, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2145]], grad_fn=<AddBackward0>)
# 14
# kernel 0 variance: tensor([[64.3526]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(30.5095, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2153]], grad_fn=<AddBackward0>)
# 15
# kernel 0 variance: tensor([[69.2810]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(32.4873, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2160]], grad_fn=<AddBackward0>)
# 16
# kernel 0 variance: tensor([[75.2954]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(33.9757, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2161]], grad_fn=<AddBackward0>)
# 17
# kernel 0 variance: tensor([[81.4444]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(34.9479, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2163]], grad_fn=<AddBackward0>)
# 18
# kernel 0 variance: tensor([[86.5421]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(35.8857, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2162]], grad_fn=<AddBackward0>)
# 19
# kernel 0 variance: tensor([[92.9981]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(37.8062, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2157]], grad_fn=<AddBackward0>)
# 20
# kernel 0 variance: tensor([[98.9108]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(39.6486, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2157]], grad_fn=<AddBackward0>)
# 21
# kernel 0 variance: tensor([[105.6385]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(42.0314, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2154]], grad_fn=<AddBackward0>)
# 22
# kernel 0 variance: tensor([[111.4823]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(43.0909, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2161]], grad_fn=<AddBackward0>)
# 23
# kernel 0 variance: tensor([[115.9749]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(45.1129, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2155]], grad_fn=<AddBackward0>)
# 24
# kernel 0 variance: tensor([[119.1861]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(46.7690, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 25
# kernel 0 variance: tensor([[124.6503]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(47.9040, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2156]], grad_fn=<AddBackward0>)
# 26
# kernel 0 variance: tensor([[128.3503]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(48.9723, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 27
# kernel 0 variance: tensor([[131.5607]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(49.5756, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2156]], grad_fn=<AddBackward0>)
# 28
# kernel 0 variance: tensor([[135.7190]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(50.5493, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2160]], grad_fn=<AddBackward0>)
# 29
# kernel 0 variance: tensor([[140.6870]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(52.0061, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2160]], grad_fn=<AddBackward0>)
# 30
# kernel 0 variance: tensor([[144.2253]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(53.5924, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2162]], grad_fn=<AddBackward0>)
# 31
# kernel 0 variance: tensor([[146.7329]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(54.0377, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2162]], grad_fn=<AddBackward0>)
# 32
# kernel 0 variance: tensor([[151.2046]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(54.5185, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2154]], grad_fn=<AddBackward0>)
# 33
# kernel 0 variance: tensor([[155.2094]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(55.4863, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2158]], grad_fn=<AddBackward0>)
# 34
# kernel 0 variance: tensor([[159.4404]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(56.4420, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2158]], grad_fn=<AddBackward0>)
# 35
# kernel 0 variance: tensor([[162.1621]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(56.5130, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2160]], grad_fn=<AddBackward0>)
# 36
# kernel 0 variance: tensor([[165.0313]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(56.7673, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2159]], grad_fn=<AddBackward0>)
# 37
# kernel 0 variance: tensor([[169.0023]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(56.4066, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2157]], grad_fn=<AddBackward0>)
# 38
# kernel 0 variance: tensor([[171.3840]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(56.0393, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2153]], grad_fn=<AddBackward0>)
# 39
# kernel 0 variance: tensor([[172.7970]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(54.4910, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2153]], grad_fn=<AddBackward0>)
# 40
# kernel 0 variance: tensor([[174.3109]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(53.0216, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2154]], grad_fn=<AddBackward0>)
# 41
# kernel 0 variance: tensor([[175.3789]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(51.3821, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 42
# kernel 0 variance: tensor([[176.4582]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(49.9176, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2146]], grad_fn=<AddBackward0>)
# 43
# kernel 0 variance: tensor([[177.6139]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(48.4526, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2149]], grad_fn=<AddBackward0>)
# 44
# kernel 0 variance: tensor([[178.6810]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(46.8577, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2142]], grad_fn=<AddBackward0>)
# 45
# kernel 0 variance: tensor([[179.9359]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(45.4397, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2135]], grad_fn=<AddBackward0>)
# 46
# kernel 0 variance: tensor([[180.9288]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(43.9447, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2139]], grad_fn=<AddBackward0>)
# 47
# kernel 0 variance: tensor([[181.4719]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(41.9911, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2142]], grad_fn=<AddBackward0>)
# 48
# kernel 0 variance: tensor([[182.0471]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(40.1048, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2146]], grad_fn=<AddBackward0>)
# 49
# kernel 0 variance: tensor([[182.3762]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(37.8517, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2148]], grad_fn=<AddBackward0>)
# 50
# kernel 0 variance: tensor([[182.3785]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(35.8297, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2147]], grad_fn=<AddBackward0>)
# 51
# kernel 0 variance: tensor([[182.4281]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(33.7444, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2144]], grad_fn=<AddBackward0>)
# 52
# kernel 0 variance: tensor([[182.3699]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(32.0924, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2143]], grad_fn=<AddBackward0>)
# 53
# kernel 0 variance: tensor([[182.6410]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(31.1316, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2148]], grad_fn=<AddBackward0>)
# 54
# kernel 0 variance: tensor([[182.8500]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(30.1102, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 55
# kernel 0 variance: tensor([[183.0091]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(29.1218, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 56
# kernel 0 variance: tensor([[183.1846]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(28.2950, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 57
# kernel 0 variance: tensor([[183.1427]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(27.3169, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 58
# kernel 0 variance: tensor([[183.4032]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(26.9232, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2151]], grad_fn=<AddBackward0>)
# 59
# kernel 0 variance: tensor([[183.5397]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(26.1792, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2151]], grad_fn=<AddBackward0>)
# 60
# kernel 0 variance: tensor([[183.3423]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(25.2362, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 61
# kernel 0 variance: tensor([[183.1384]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(24.5455, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2149]], grad_fn=<AddBackward0>)
# 62
# kernel 0 variance: tensor([[183.0823]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(23.5592, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 63
# kernel 0 variance: tensor([[182.9032]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(22.2869, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2151]], grad_fn=<AddBackward0>)
# 64
# kernel 0 variance: tensor([[182.4798]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(20.6850, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2152]], grad_fn=<AddBackward0>)
# 65
# kernel 0 variance: tensor([[182.0794]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(19.2409, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 66
# kernel 0 variance: tensor([[181.5093]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(17.2837, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2150]], grad_fn=<AddBackward0>)
# 67
# kernel 0 variance: tensor([[180.7694]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(15.5446, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2148]], grad_fn=<AddBackward0>)
# 68
# kernel 0 variance: tensor([[179.8926]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(13.7057, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2148]], grad_fn=<AddBackward0>)
# 69
# kernel 0 variance: tensor([[179.0029]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(12.3225, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2146]], grad_fn=<AddBackward0>)
# 70
# kernel 0 variance: tensor([[177.8898]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(11.0029, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2147]], grad_fn=<AddBackward0>)
# 71
# kernel 0 variance: tensor([[176.7102]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.3866, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2144]], grad_fn=<AddBackward0>)
# 72
# kernel 0 variance: tensor([[175.3635]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.2044, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2138]], grad_fn=<AddBackward0>)
# 73
# kernel 0 variance: tensor([[174.1302]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.2646, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2138]], grad_fn=<AddBackward0>)
# 74
# kernel 0 variance: tensor([[172.9173]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.5939, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2134]], grad_fn=<AddBackward0>)
# 75
# kernel 0 variance: tensor([[171.5180]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.3644, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2135]], grad_fn=<AddBackward0>)
# 76
# kernel 0 variance: tensor([[170.1970]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.5540, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2135]], grad_fn=<AddBackward0>)
# 77
# kernel 0 variance: tensor([[168.6837]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.4614, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2135]], grad_fn=<AddBackward0>)
# 78
# kernel 0 variance: tensor([[167.4368]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.8249, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2133]], grad_fn=<AddBackward0>)
# 79
# kernel 0 variance: tensor([[166.3182]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(11.0205, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2133]], grad_fn=<AddBackward0>)
# 80
# kernel 0 variance: tensor([[165.2443]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(11.0506, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2133]], grad_fn=<AddBackward0>)
# 81
# kernel 0 variance: tensor([[164.1899]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.9661, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2134]], grad_fn=<AddBackward0>)
# 82
# kernel 0 variance: tensor([[163.1150]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.7955, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2131]], grad_fn=<AddBackward0>)
# 83
# kernel 0 variance: tensor([[161.9659]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.4028, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2131]], grad_fn=<AddBackward0>)
# 84
# kernel 0 variance: tensor([[160.6519]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.1411, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2130]], grad_fn=<AddBackward0>)
# 85
# kernel 0 variance: tensor([[159.4366]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.1657, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2126]], grad_fn=<AddBackward0>)
# 86
# kernel 0 variance: tensor([[158.1475]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(10.0357, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2126]], grad_fn=<AddBackward0>)
# 87
# kernel 0 variance: tensor([[156.7446]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(9.7300, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2126]], grad_fn=<AddBackward0>)
# 88
# kernel 0 variance: tensor([[155.1239]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(9.3868, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 89
# kernel 0 variance: tensor([[153.4946]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(9.1602, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 90
# kernel 0 variance: tensor([[151.7369]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.7926, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 91
# kernel 0 variance: tensor([[150.0238]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.6667, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2125]], grad_fn=<AddBackward0>)
# 92
# kernel 0 variance: tensor([[148.2064]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.3829, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2127]], grad_fn=<AddBackward0>)
# 93
# kernel 0 variance: tensor([[146.2481]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.1573, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 94
# kernel 0 variance: tensor([[144.2745]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.1672, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 95
# kernel 0 variance: tensor([[142.4496]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.3494, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2126]], grad_fn=<AddBackward0>)
# 96
# kernel 0 variance: tensor([[140.7666]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.5451, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2123]], grad_fn=<AddBackward0>)
# 97
# kernel 0 variance: tensor([[139.0317]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.5063, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2118]], grad_fn=<AddBackward0>)
# 98
# kernel 0 variance: tensor([[137.2414]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.3602, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2114]], grad_fn=<AddBackward0>)
# 99
# kernel 0 variance: tensor([[135.4898]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.2917, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2119]], grad_fn=<AddBackward0>)
# 100
# kernel 0 variance: tensor([[133.7749]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.1446, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2119]], grad_fn=<AddBackward0>)
# kernel 0 variance: tensor([[133.7749]], grad_fn=<SoftplusBackward0>)
# kernel 1 outputscale: tensor(8.1446, grad_fn=<SoftplusBackward0>)
# kernel 1 lengthscale: tensor([[0.2119]], grad_fn=<AddBackward0>)

# %% [markdown]
# ## Plot figure

# %%
# %matplotlib inline
plt.tight_layout()

rmse_values = []

# Create a figure and define the grid
fig = plt.figure(figsize=(figure_width, figure_height), dpi=dpi_val)
gs = GridSpec(num_plot_rows, num_plot_columns, width_ratios=[4, 2.5]) 

for i in range(len(phenos)):

    ############
    # PLOTTING #
    ############
    
    title, _ = phenos[i]
    
    pheno_results_dict = results[i]
    
    xx = pheno_results_dict['xx']
    yy = pheno_results_dict['yy']
    zz = pheno_results_dict['zz']
    X = pheno_results_dict['X']
    y = pheno_results_dict['y']
    left = pheno_results_dict['left']
    right = pheno_results_dict['right']
    top = pheno_results_dict['top']
    bottom = pheno_results_dict['bottom']
    cs = pheno_results_dict['cs']
    psi_sigma = pheno_results_dict['psi_sigma']
    psi_gamma = pheno_results_dict['psi_gamma']
    psi_lambda = pheno_results_dict['psi_lambda']
    x_min = pheno_results_dict['x_min']
    x_max = pheno_results_dict['x_max']
    y_min = pheno_results_dict['y_min']
    y_max = pheno_results_dict['y_max']
    xs = pheno_results_dict['xs']
    ys = pheno_results_dict['ys']
    entropy_list = pheno_results_dict['entropy_list']
    initial_points = pheno_results_dict['initial_points']
    grid = pheno_results_dict['grid']
    f = pheno_results_dict['f']
    posterior_list = pheno_results_dict['posterior_list']
    rmse_list = pheno_results_dict['rmse']
    
    print(rmse_list[-1])
    rmse = rmse_list[-1]
    
    rmse_values.append(f'{title}: ' + str(rmse_list[-1]))
    
    model = posterior_list[-1][0]
    likelihood = posterior_list[-1][1]
    zz = evaluate_posterior_mean(model, likelihood, grid_transformed).reshape(xx.shape)
    
    ##########
    # PLOT A #
    ##########

    ax1 = plt.subplot(gs[0:num_plot_rows, 0])  # Span all rows in the first column


    # plot the contour field
    if plot_a_prior:
        plt.pcolormesh(xx, yy, zz, cmap=a_prior_color_gradient, vmin=a_prior_grad_min, 
                       vmax=a_prior_grad_max, zorder = posterior_zorder)
        cbar = plt.colorbar(pad=fig_a_cb_pad) 
        cbar.set_ticks(fig_a_cb_ticks)
        cbar.set_ticklabels(fig_a_cb_labs)
        cbar.set_label(fig_a_cb_label, labelpad=fig_a_cb_label_pad)

    # plot the training data
    if plot_a_data:
        x1_failure = X[y == 0, 0].reshape(-1)
        x2_failure = X[y == 0, 1].reshape(-1)
        x1_success = X[y == 1, 0].reshape(-1)
        x2_success = X[y == 1, 1].reshape(-1)
        # Create diamond corner array
        diamond_corners = np.array([
                                  [x1_failure, x2_failure + diamond_height*diamond_size],
                                  [x1_failure + diamond_width*diamond_size, x2_failure],
                                  [x1_failure, x2_failure - diamond_height*diamond_size],
                                  [x1_failure - diamond_width*diamond_size, x2_failure]])
        plt.scatter(x1_success, x2_success, marker =success_marker, s=marker_size, color=success_color, 
                    linewidth=plus_line_width, zorder=success_zorder, label=success_label)
        plt.fill(diamond_corners[:, 0], diamond_corners[:, 1], \
                 color=diamond_fill_color, edgecolor=failure_color, 
                 linewidth=diamond_line_width, zorder= fail_zorder, label = failure_label)

    # plot the canonical CSF
    if plot_a_canon:
        latent_x1 = np.linspace(left, x_max, num_curve_points)
        latent_x2 = cs(latent_x1)
        plt.plot(latent_x1, latent_x2, color=a_latent_color, zorder=canon_zorder)

    # plot the level curve
    if plot_a_thresh:
        level = (1 - psi_lambda + psi_gamma) / 2
        CS = plt.contour(xx, yy, zz, levels=[level], colors=a_mean_color,
                linestyles=a_linestyle, zorder=thresh_zorder)

        for c in CS.collections:
            c.set_dashes(a_dash_list)

    # add xticks and yticks and fit to grid
    plt.xticks(xticks_values, xticks_labels)
    plt.yticks(yticks_values, yticks_labels)
    plt.tick_params(**axis_tick_params, labelsize=tick_font_size)
    
    x_padding = (x_max - x_min) / (2 * (xs - 1))
    y_padding = (y_max - y_min) / (2 * (ys - 1))
    plt.xlim(x_min - x_padding, x_max + x_padding)
    plt.ylim(y_min - y_padding, y_max + y_padding)

    # title and axis labels
    plt.title(title, fontsize = title_font_size)
    plt.xlabel(a_xlab, fontsize = label_font_size)
    plt.ylabel(a_ylab, fontsize = label_font_size)

    
    ##########
    # PLOT B #
    ##########
    
    # occupy 1st and 2nd row in 2nd column
    ax2 = plt.subplot(gs[0:math.floor(num_plot_rows/2), 1])  
    
    # plot the spline
    if plot_b_canon:
        latent_x1 = np.linspace(left, x_max, num_curve_points)
        latent_x2 = cs(latent_x1)
        plt.plot(latent_x1, latent_x2, color=b_latent_color)

    # plot the level curve
    if plot_b_thresh:
        level = (1 - psi_lambda + psi_gamma) / 2
        CS = plt.contour(xx, yy, zz, levels=[level], color=b_mean_color)
        for c in CS.collections:
            c.set_dashes(b_dash_list)
            c.set_edgecolor(b_mean_color)

    # set xticks and yticks and fit to the grid
    plt.xticks(xticks_values, xticks_labels)
    plt.yticks(yticks_values, yticks_labels)
    plt.tick_params(**axis_tick_params, labelsize=tick_font_size)

    # x_padding = (x_max - x_min) / (2 * (xs - 1))
    # y_padding = (y_max - y_min) / (2 * (ys - 1))
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)

    # title, axis labels and legend
    plt.title(b_title, fontsize=title_font_size)
    plt.xlabel(b_xlab, fontsize=label_font_size)
    plt.ylabel(b_ylab, fontsize=label_font_size)

    latent = mlines.Line2D([], [], color=b_latent_color, label=latent_label)
    mean = mlines.Line2D([], [], color=b_mean_color, dashes=b_dash_tuple,
            label=mean_label)
    plt.legend(loc=b_legend_location, fontsize=legend_font_size, handles=[latent, mean], frameon=False)

    ##########
    # PLOT C #
    ##########
    
    ax3 = plt.subplot(gs[math.ceil(num_plot_rows/2):num_plot_rows, 1])  # Occupy last 2 rows in 2nd column

     # create the data set to evaluate
    log_freqs = np.full(num_curve_points, freq_to_slice_at)
    log_contrasts = np.linspace(y_min, y_max, num_curve_points)

    # plot true (simulated) outputs
    if plot_c_canonical:
        sim_outputs = simulate_sigmoid(log_freqs, log_contrasts, cs, psi_gamma, psi_lambda, \
                                       sigmoid_type = sigmoid_type, psi_sigma = psi_sigma)    
         #plot them
        plt.plot(log_contrasts, sim_outputs, color=c_latent_color)

    # plot cdf predicted by GP
    if plot_c_cdf:
        D = np.vstack((log_freqs, log_contrasts)).T
        Dt = transform_dataset(D, phi=f)
        # get the predictions on D
        GP_outputs = evaluate_posterior_mean(model, likelihood, Dt)
        plt.plot(log_contrasts, GP_outputs, color=c_mean_color, linestyle=c_dash_symbol, dashes=c_dash)
    
    ###########
    # GENERAL #
    ###########

    # A, B, and C labels for each subplot
    fig.text(*a_subplot_coords, "A", fontsize=subplot_label_font_size)
    fig.text(*b_subplot_coords, "B", fontsize=subplot_label_font_size)
    fig.text(*c_subplot_coords, "C", fontsize=subplot_label_font_size)

    # Set xticks, yticks and limits
    plt.xticks(c_xticks_values, c_xticks_labels)
    plt.yticks(c_yticks_values, c_yticks_labels)
    plt.tick_params(**axis_tick_params, labelsize=tick_font_size)
    
    plt.xlim(y_min, y_max) # y_lim is for contrast, and here contrast is on the x-axis
    plt.ylim(0, 1) # 0 to 1 for probability
    
    # title, axist labels and legend
    plt.title(c_title, fontsize=title_font_size)
    plt.xlabel(c_xlab, fontsize=label_font_size)
    plt.ylabel(c_ylab, fontsize=label_font_size)
    plt.legend(loc=c_legend_location, fontsize=legend_font_size, handles=[latent, mean], frameon=False)

    # Save fit quality
    if (save_mode and save_rmse):
        ensure_directory_exists(save_dir)
        filename = rmse_txt_path
        with open(filename, 'w') as file:
            for string in rmse_values:
                file.write(string + '\n')
    
# Show and/or save figure 
if save_mode:
    ensure_directory_exists(save_dir)
    plt.savefig(a_png_path, bbox_inches='tight', dpi=dpi_val)
    plt.savefig(a_pdf_path, bbox_inches='tight', dpi=dpi_val)
if scrn_mode:
    plt.show()
else:
    plt.clf()
# Out:
# 0.0762250312832644
